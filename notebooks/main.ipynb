# %%
# %pip install -r ../requirements.txt

# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
import torch
import torchvision

print(torch.__version__)
print(torchvision.__version__)
# Out:
# 2.11.0+cu130
# 0.26.0+cu130

# %% [markdown]
# ## Laboratory

# %%
# %cd ..
# Out:
# /home/shuptik/pw/sem6/ann/AnimalImageClassification

# %% [markdown]
# Run from the project root

# %%
# !python ./main.py
# Out:
# GPU not available, using CPU
#
# Q5:
#
# Epoch 1/5:
# Train Acc: 0.4719. Train Loss: 5.0212
# Val Acc: 0.5000. Val Loss: 6.4639
# F1-score for class : bears - 0.0
# F1-score for class : elephants - 0.6666666666666666
# The weakest three classes:
# 1. bears - 0.0
# 2. elephants - 0.6666666666666666
#
# Epoch 2/5:
# Train Acc: 0.5938. Train Loss: 2.8409
# Val Acc: 0.6750. Val Loss: 1.0573
# F1-score for class : bears - 0.6486486486486486
# F1-score for class : elephants - 0.6976744186046512
# The weakest three classes:
# 1. bears - 0.6486486486486486
# 2. elephants - 0.6976744186046512
#
# Epoch 3/5:
# Train Acc: 0.7500. Train Loss: 1.2225
# Val Acc: 0.6500. Val Loss: 1.4910
# F1-score for class : bears - 0.7358490566037736
# F1-score for class : elephants - 0.48148148148148157
# The weakest three classes:
# 1. elephants - 0.48148148148148157
# 2. bears - 0.7358490566037736
#
# Epoch 4/5:
# Train Acc: 0.7344. Train Loss: 0.9114
# Val Acc: 0.6250. Val Loss: 2.0028
# F1-score for class : bears - 0.4230769230769231
# F1-score for class : elephants - 0.7222222222222222
# The weakest three classes:
# 1. bears - 0.4230769230769231
# 2. elephants - 0.7222222222222222
#
# Epoch 5/5:
# Train Acc: 0.7906. Train Loss: 0.7372
# Val Acc: 0.6750. Val Loss: 1.1047
# F1-score for class : bears - 0.7499999999999999
# F1-score for class : elephants - 0.5357142857142857
# The weakest three classes:
# 1. elephants - 0.5357142857142857
# 2. bears - 0.7499999999999999
# Best accuracy over epochs: 0.675
# The plot was saved to /home/shuptik/pw/sem6/ann/AnimalImageClassification/plots/val_acc_per_epochs.png
#
# Q7- Hyperparameter tuning
#
# --------------------------------------------------
#
# filter_size=32, lr=0.001, batch_size=64, weight_decay=0
#
# Epoch 1/3:
# Train Acc: 0.5188. Train Loss: 3.3733
# Val Acc: 0.5625. Val Loss: 1.8306
# F1-score for class : bears - 0.36363636363636365
# F1-score for class : elephants - 0.6666666666666667
# The weakest three classes:
# 1. bears - 0.36363636363636365
# 2. elephants - 0.6666666666666667
#
# Epoch 2/3:
# Train Acc: 0.7594. Train Loss: 1.2322
# Val Acc: 0.6500. Val Loss: 1.6656
# F1-score for class : bears - 0.5333333333333333
# F1-score for class : elephants - 0.7200000000000001
# The weakest three classes:
# 1. bears - 0.5333333333333333
# 2. elephants - 0.7200000000000001
#
# Epoch 3/3:
# Train Acc: 0.8000. Train Loss: 0.7288
# Val Acc: 0.7250. Val Loss: 0.7829
# F1-score for class : bears - 0.7659574468085106
# F1-score for class : elephants - 0.6666666666666667
# The weakest three classes:
# 1. elephants - 0.6666666666666667
# 2. bears - 0.7659574468085106
#
# --------------------------------------------------
#
# filter_size=32, lr=0.001, batch_size=64, weight_decay=0.0001
#
# Epoch 1/3:
# Train Acc: 0.5312. Train Loss: 2.8584
# Val Acc: 0.5500. Val Loss: 2.8275
# F1-score for class : bears - 0.21739130434782608
# F1-score for class : elephants - 0.6842105263157895
# The weakest three classes:
# 1. bears - 0.21739130434782608
# 2. elephants - 0.6842105263157895
#
# Epoch 2/3:
# Train Acc: 0.6750. Train Loss: 1.3891
# Val Acc: 0.6125. Val Loss: 1.3196
# F1-score for class : bears - 0.392156862745098
# F1-score for class : elephants - 0.7155963302752294
# The weakest three classes:
# 1. bears - 0.392156862745098
# 2. elephants - 0.7155963302752294
#
# Epoch 3/3:
# Train Acc: 0.7375. Train Loss: 0.7172
# Val Acc: 0.6750. Val Loss: 0.9338
# F1-score for class : bears - 0.7547169811320755
# F1-score for class : elephants - 0.5185185185185185
# The weakest three classes:
# 1. elephants - 0.5185185185185185
# 2. bears - 0.7547169811320755
#
# --------------------------------------------------
#
# filter_size=32, lr=0.001, batch_size=128, weight_decay=0
#
# Epoch 1/3:
# Train Acc: 0.4875. Train Loss: 4.0900
# Val Acc: 0.5500. Val Loss: 2.1142
# F1-score for class : bears - 0.24999999999999997
# F1-score for class : elephants - 0.6785714285714285
# The weakest three classes:
# 1. bears - 0.24999999999999997
# 2. elephants - 0.6785714285714285
#
# Epoch 2/3:
# Train Acc: 0.5813. Train Loss: 1.7939
# Val Acc: 0.6000. Val Loss: 0.8478
# F1-score for class : bears - 0.6097560975609756
# F1-score for class : elephants - 0.5897435897435896
# The weakest three classes:
# 1. elephants - 0.5897435897435896
# 2. bears - 0.6097560975609756
#
# Epoch 3/3:
# Train Acc: 0.6750. Train Loss: 1.2987
# Val Acc: 0.6125. Val Loss: 0.8311
# F1-score for class : bears - 0.507936507936508
# F1-score for class : elephants - 0.6804123711340206
# The weakest three classes:
# 1. bears - 0.507936507936508
# 2. elephants - 0.6804123711340206
#
# --------------------------------------------------
#
# filter_size=32, lr=0.001, batch_size=128, weight_decay=0.0001
#
# Epoch 1/3:
# Train Acc: 0.5250. Train Loss: 5.1256
# Val Acc: 0.5125. Val Loss: 5.7841
# F1-score for class : bears - 0.6722689075630253
# F1-score for class : elephants - 0.04878048780487806
# The weakest three classes:
# 1. elephants - 0.04878048780487806
# 2. bears - 0.6722689075630253
#
# Epoch 2/3:
# Train Acc: 0.5938. Train Loss: 2.9654
# Val Acc: 0.5125. Val Loss: 4.1351
# F1-score for class : bears - 0.04878048780487806
# F1-score for class : elephants - 0.6722689075630253
# The weakest three classes:
# 1. bears - 0.04878048780487806
# 2. elephants - 0.6722689075630253
#
# Epoch 3/3:
# Train Acc: 0.6375. Train Loss: 2.0724
# Val Acc: 0.5875. Val Loss: 2.7648
# F1-score for class : bears - 0.7027027027027027
# F1-score for class : elephants - 0.326530612244898
# The weakest three classes:
# 1. elephants - 0.326530612244898
# 2. bears - 0.7027027027027027
#
# --------------------------------------------------
#
# filter_size=32, lr=0.0003, batch_size=64, weight_decay=0
#
# Epoch 1/3:
# Train Acc: 0.5406. Train Loss: 1.3520
# Val Acc: 0.5125. Val Loss: 1.4481
# F1-score for class : bears - 0.6486486486486486
# F1-score for class : elephants - 0.20408163265306123
# The weakest three classes:
# 1. elephants - 0.20408163265306123
# 2. bears - 0.6486486486486486
#
# Epoch 2/3:
# Train Acc: 0.5656. Train Loss: 1.3489
# Val Acc: 0.5500. Val Loss: 1.4149
# F1-score for class : bears - 0.18181818181818182
# F1-score for class : elephants - 0.6896551724137931
# The weakest three classes:
# 1. bears - 0.18181818181818182
# 2. elephants - 0.6896551724137931
#
# Epoch 3/3:
# Train Acc: 0.6656. Train Loss: 0.7791
# Val Acc: 0.6125. Val Loss: 0.7488
# F1-score for class : bears - 0.7047619047619047
# F1-score for class : elephants - 0.4363636363636363
# The weakest three classes:
# 1. elephants - 0.4363636363636363
# 2. bears - 0.7047619047619047
#
# --------------------------------------------------
#
# filter_size=32, lr=0.0003, batch_size=64, weight_decay=0.0001
#
# Epoch 1/3:
# Train Acc: 0.5375. Train Loss: 1.3222
# Val Acc: 0.5375. Val Loss: 0.9829
# F1-score for class : bears - 0.6476190476190476
# F1-score for class : elephants - 0.3272727272727273
# The weakest three classes:
# 1. elephants - 0.3272727272727273
# 2. bears - 0.6476190476190476
#
# Epoch 2/3:
# Train Acc: 0.6687. Train Loss: 0.7939
# Val Acc: 0.6500. Val Loss: 0.6135
# F1-score for class : bears - 0.6216216216216216
# F1-score for class : elephants - 0.6744186046511628
# The weakest three classes:
# 1. bears - 0.6216216216216216
# 2. elephants - 0.6744186046511628
#
# Epoch 3/3:
# Train Acc: 0.7625. Train Loss: 0.5061
# Val Acc: 0.6750. Val Loss: 0.6144
# F1-score for class : bears - 0.6176470588235295
# F1-score for class : elephants - 0.717391304347826
# The weakest three classes:
# 1. bears - 0.6176470588235295
# 2. elephants - 0.717391304347826
#
# --------------------------------------------------
#
# filter_size=32, lr=0.0003, batch_size=128, weight_decay=0
#
# Epoch 1/3:
# Train Acc: 0.5625. Train Loss: 1.4555
# Val Acc: 0.6000. Val Loss: 0.8868
# F1-score for class : bears - 0.7090909090909092
# F1-score for class : elephants - 0.36000000000000004
# The weakest three classes:
# 1. elephants - 0.36000000000000004
# 2. bears - 0.7090909090909092
#
# Epoch 2/3:
# Train Acc: 0.5469. Train Loss: 1.5291
# Val Acc: 0.5625. Val Loss: 1.4073
# F1-score for class : bears - 0.2222222222222222
# F1-score for class : elephants - 0.6956521739130436
# The weakest three classes:
# 1. bears - 0.2222222222222222
# 2. elephants - 0.6956521739130436
#
# Epoch 3/3:
# Train Acc: 0.6687. Train Loss: 0.9036
# Val Acc: 0.5750. Val Loss: 1.3525
# F1-score for class : bears - 0.6964285714285714
# F1-score for class : elephants - 0.29166666666666663
# The weakest three classes:
# 1. elephants - 0.29166666666666663
# 2. bears - 0.6964285714285714
#
# --------------------------------------------------
#
# filter_size=32, lr=0.0003, batch_size=128, weight_decay=0.0001
