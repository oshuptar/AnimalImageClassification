# %%
# %pip install -r ../requirements.txt

# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
import torch
import torchvision

print(torch.__version__)
print(torchvision.__version__)
# Out:
# 2.11.0+cu130
# 0.26.0+cu130

# %% [markdown]
# ## Laboratory

# %%
# %cd ..
# Out:
# /home/shuptik/pw/sem6/ann/AnimalImageClassification

# %% [markdown]
# Run from the project root

# %%
# !python ./main.py
# Out:
# GPU not available, using CPU
#
# Q5:
#
# Epoch 1/5:
# Train Acc: 0.5406. Train Loss: 2.6896
# Val Acc: 0.6375. Val Loss: 1.5701
# F1-score for class : bears - 0.5797101449275363
# F1-score for class : elephants - 0.6813186813186813
# The weakest three classes:
# 1. bears - 0.5797101449275363
# 2. elephants - 0.6813186813186813
#
# Epoch 2/5:
# Train Acc: 0.6750. Train Loss: 1.8923
# Val Acc: 0.6375. Val Loss: 2.0363
# F1-score for class : bears - 0.7339449541284404
# F1-score for class : elephants - 0.4313725490196079
# The weakest three classes:
# 1. elephants - 0.4313725490196079
# 2. bears - 0.7339449541284404
#
# Epoch 3/5:
# Train Acc: 0.6937. Train Loss: 1.2610
# Val Acc: 0.7375. Val Loss: 1.1968
# F1-score for class : bears - 0.6865671641791045
# F1-score for class : elephants - 0.7741935483870968
# The weakest three classes:
# 1. bears - 0.6865671641791045
# 2. elephants - 0.7741935483870968
#
# Epoch 4/5:
# Train Acc: 0.8031. Train Loss: 0.7209
# Val Acc: 0.6875. Val Loss: 1.2580
# F1-score for class : bears - 0.5901639344262294
# F1-score for class : elephants - 0.7474747474747475
# The weakest three classes:
# 1. bears - 0.5901639344262294
# 2. elephants - 0.7474747474747475
#
# Epoch 5/5:
# Train Acc: 0.8438. Train Loss: 0.5532
# Val Acc: 0.7625. Val Loss: 0.7409
# F1-score for class : bears - 0.7956989247311829
# F1-score for class : elephants - 0.7164179104477612
# The weakest three classes:
# 1. elephants - 0.7164179104477612
# 2. bears - 0.7956989247311829
# Best accuracy over epochs: 0.7625
# The plot was saved to /home/shuptik/pw/sem6/ann/AnimalImageClassification/plots/val_acc_per_epochs.png
#
# Q7- Hyperparameter tuning
#
# Q8
#
# Q9
# Benchmark results: throughput = 298.1479229688987img/s
