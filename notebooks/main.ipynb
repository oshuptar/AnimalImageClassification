# %%
# %pip install -r ../requirements.txt

# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
import torch
import torchvision

print(torch.__version__)
print(torchvision.__version__)
# Out:
# 2.11.0+cu130
# 0.26.0+cu130

# %% [markdown]
# ## Laboratory

# %%
# %cd ..
# Out:
# /home/shuptik/pw/sem6/ann/AnimalImageClassification

# %% [markdown]
# Run from the project root

# %%
# !python ./main.py
# Out:
# GPU not available, using CPU
#
# Q1:
#
# Epoch 1/10:
# Train Acc: 0.60625. Train Loss: 0.6562
# Val Acc: 0.575. Val Loss: 0.6513499021530151
#
# Epoch 2/10:
# Train Acc: 0.70625. Train Loss: 0.5700
# Val Acc: 0.5875. Val Loss: 0.6271911561489105
#
# Epoch 3/10:
# Train Acc: 0.778125. Train Loss: 0.5149
# Val Acc: 0.6125. Val Loss: 0.5938594937324524
#
# Epoch 4/10:
# Train Acc: 0.746875. Train Loss: 0.5034
# Val Acc: 0.6625. Val Loss: 0.6095536351203918
#
# Epoch 5/10:
# Train Acc: 0.796875. Train Loss: 0.4695
# Val Acc: 0.6625. Val Loss: 0.5724782943725586
#
# Epoch 6/10:
# Train Acc: 0.790625. Train Loss: 0.4474
# Val Acc: 0.6875. Val Loss: 0.6058946251869202
#
# Epoch 7/10:
# Train Acc: 0.828125. Train Loss: 0.4184
# Val Acc: 0.675. Val Loss: 0.5716065466403961
#
# Epoch 8/10:
# Train Acc: 0.85. Train Loss: 0.3986
# Val Acc: 0.725. Val Loss: 0.562936544418335
#
# Epoch 9/10:
# Train Acc: 0.85. Train Loss: 0.3891
# Val Acc: 0.6875. Val Loss: 0.564010888338089
#
# Epoch 10/10:
# Train Acc: 0.8375. Train Loss: 0.3840
# Val Acc: 0.6625. Val Loss: 0.5719759464263916
