# %%
# %pip install -r ../requirements.txt

# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
import torch
import torchvision

print(torch.__version__)
print(torchvision.__version__)
# Out:
# 2.11.0+cu130
# 0.26.0+cu130

# %% [markdown]
# ## Laboratory

# %%
# %cd ..
# Out:
# /home/shuptik/pw/sem6/ann/AnimalImageClassification

# %% [markdown]
# Run from the project root

# %%
# !python ./main.py
# Out:
# GPU not available, using CPU
#
# Q5:
#
# Epoch 1/5:
# Train Acc: 0.5250. Train Loss: 4.2306
# Val Acc: 0.5625. Val Loss: 2.2219
# F1-score for class : bears - 0.6534653465346534
# F1-score for class : elephants - 0.4067796610169491
# The weakest three classes:
# 1. elephants - 0.4067796610169491
# 2. bears - 0.6534653465346534
#
# Epoch 2/5:
# Train Acc: 0.6031. Train Loss: 2.3165
# Val Acc: 0.5625. Val Loss: 3.3982
# F1-score for class : bears - 0.2553191489361702
# F1-score for class : elephants - 0.6902654867256637
# The weakest three classes:
# 1. bears - 0.2553191489361702
# 2. elephants - 0.6902654867256637
#
# Epoch 3/5:
# Train Acc: 0.6844. Train Loss: 1.1689
# Val Acc: 0.7250. Val Loss: 0.9511
# F1-score for class : bears - 0.7708333333333333
# F1-score for class : elephants - 0.6562500000000001
# The weakest three classes:
# 1. elephants - 0.6562500000000001
# 2. bears - 0.7708333333333333
#
# Epoch 4/5:
# Train Acc: 0.7906. Train Loss: 0.7749
# Val Acc: 0.6875. Val Loss: 0.7463
# F1-score for class : bears - 0.6153846153846154
# F1-score for class : elephants - 0.7368421052631579
# The weakest three classes:
# 1. bears - 0.6153846153846154
# 2. elephants - 0.7368421052631579
#
# Epoch 5/5:
# Train Acc: 0.8562. Train Loss: 0.3419
# Val Acc: 0.7250. Val Loss: 0.6748
# F1-score for class : bears - 0.7105263157894738
# F1-score for class : elephants - 0.7380952380952381
# The weakest three classes:
# 1. bears - 0.7105263157894738
# 2. elephants - 0.7380952380952381
# Best accuracy over epochs: 0.725
# The plot was saved to /home/shuptik/pw/sem6/ann/AnimalImageClassification/plots/val_acc_per_epochs.png
#
# Q7- Hyperparameter tuning
#
# Q8
# The plot was saved to /home/shuptik/pw/sem6/ann/AnimalImageClassification/plots/confusion_matrix_heatmap.png
