# %%
# %pip install -r ../requirements.txt

# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
import torch
import torchvision

print(torch.__version__)
print(torchvision.__version__)
# Out:
# 2.11.0+cu130
# 0.26.0+cu130

# %% [markdown]
# ## Laboratory

# %%
# %cd ..
# Out:
# /home/shuptik/pw/sem6/ann/AnimalImageClassification

# %% [markdown]
# Run from the project root

# %%
# !python ./main.py
# Out:
# GPU not available, using CPU
#
# Q5:
#
# Epoch 1/5:
# Train Acc: 0.5375. Train Loss: 2.6528
# Val Acc: 0.575. Val Loss: 1.526142954826355
#
# Epoch 2/5:
# Train Acc: 0.725. Train Loss: 1.2064
# Val Acc: 0.65. Val Loss: 1.8288179636001587
#
# Epoch 3/5:
# Train Acc: 0.759375. Train Loss: 0.8640
# Val Acc: 0.775. Val Loss: 0.6385649740695953
#
# Epoch 4/5:
# Train Acc: 0.85. Train Loss: 0.4424
# Val Acc: 0.7625. Val Loss: 0.5203343331813812
#
# Epoch 5/5:
# Train Acc: 0.925. Train Loss: 0.2556
# Val Acc: 0.85. Val Loss: 0.4144170582294464
# Best accuracy over epochs: 0.85
# The plot was saved to /home/shuptik/pw/sem6/ann/AnimalImageClassification/plots/val_acc_per_epochs.png
#
# Q6
# F1-score for class : bears - 0.7592245153220762
# F1-score for class : elephants - 0.759525296689569
# The weakest three classes:
# 1. bears - 0.7592245153220762
# 2. elephants - 0.759525296689569
