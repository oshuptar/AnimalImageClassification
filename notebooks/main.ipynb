# %%
# %pip install -r ../requirements.txt

# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
import torch
import torchvision

print(torch.__version__)
print(torchvision.__version__)
# Out:
# 2.11.0+cu130
# 0.26.0+cu130

# %% [markdown]
# ## Laboratory

# %%
# %cd ..
# Out:
# /home/shuptik/pw/sem6/ann/AnimalImageClassification

# %% [markdown]
# Run from the project root

# %%
# !python ./main.py
# Out:
# GPU not available, using CPU
#
# Q5:
#
# Epoch 1/5:
# Train Acc: 0.4781. Train Loss: 7.9041
# Val Acc: 0.5000. Val Loss: 11.4786
# F1-score for class : bears - 0.0
# F1-score for class : elephants - 0.6666666666666666
# The weakest three classes:
# 1. bears - 0.0
# 2. elephants - 0.6666666666666666
#
# Epoch 2/5:
# Train Acc: 0.5437. Train Loss: 5.5302
# Val Acc: 0.5000. Val Loss: 5.6651
# F1-score for class : bears - 0.6666666666666666
# F1-score for class : elephants - 0.0
# The weakest three classes:
# 1. elephants - 0.0
# 2. bears - 0.6666666666666666
#
# Epoch 3/5:
# Train Acc: 0.5906. Train Loss: 3.2216
# Val Acc: 0.5250. Val Loss: 4.3614
# F1-score for class : bears - 0.09523809523809523
# F1-score for class : elephants - 0.6779661016949152
# The weakest three classes:
# 1. bears - 0.09523809523809523
# 2. elephants - 0.6779661016949152
#
# Epoch 4/5:
# Train Acc: 0.6469. Train Loss: 1.8793
# Val Acc: 0.6500. Val Loss: 1.0517
# F1-score for class : bears - 0.7358490566037736
# F1-score for class : elephants - 0.48148148148148157
# The weakest three classes:
# 1. elephants - 0.48148148148148157
# 2. bears - 0.7358490566037736
#
# Epoch 5/5:
# Train Acc: 0.6594. Train Loss: 1.1811
# Val Acc: 0.6750. Val Loss: 0.8491
# F1-score for class : bears - 0.6060606060606061
# F1-score for class : elephants - 0.723404255319149
# The weakest three classes:
# 1. bears - 0.6060606060606061
# 2. elephants - 0.723404255319149
# Best accuracy over epochs: 0.675
# The plot was saved to /home/shuptik/pw/sem6/ann/AnimalImageClassification/plots/val_acc_per_epochs.png
#
# Q7- Hyperparameter tuning
#
# --------------------------------------------------
#
# filter_size=32, lr=0.001, batch_size=64, weight_decay=0
#
# Epoch 1/3:
# Train Acc: 0.5094. Train Loss: 3.0001
# Val Acc: 0.5000. Val Loss: 2.6520
# F1-score for class : bears - 0.047619047619047616
# F1-score for class : elephants - 0.6610169491525423
# The weakest three classes:
# 1. bears - 0.047619047619047616
# 2. elephants - 0.6610169491525423
#
# Epoch 2/3:
# Train Acc: 0.6531. Train Loss: 1.3488
# Val Acc: 0.6500. Val Loss: 1.0962
# F1-score for class : bears - 0.5483870967741935
# F1-score for class : elephants - 0.7142857142857142
# The weakest three classes:
# 1. bears - 0.5483870967741935
# 2. elephants - 0.7142857142857142
#
# Epoch 3/3:
# Train Acc: 0.7812. Train Loss: 0.5966
# Val Acc: 0.6750. Val Loss: 0.7862
# F1-score for class : bears - 0.7450980392156863
# F1-score for class : elephants - 0.5517241379310346
# The weakest three classes:
# 1. elephants - 0.5517241379310346
# 2. bears - 0.7450980392156863
#
# --------------------------------------------------
#
# filter_size=32, lr=0.001, batch_size=64, weight_decay=0.0001
#
# Epoch 1/3:
# Train Acc: 0.5781. Train Loss: 2.6620
# Val Acc: 0.5750. Val Loss: 1.6982
# F1-score for class : bears - 0.6909090909090908
# F1-score for class : elephants - 0.32000000000000006
# The weakest three classes:
# 1. elephants - 0.32000000000000006
# 2. bears - 0.6909090909090908
#
# Epoch 2/3:
# Train Acc: 0.6562. Train Loss: 1.4319
# Val Acc: 0.6375. Val Loss: 1.6009
# F1-score for class : bears - 0.4912280701754386
# F1-score for class : elephants - 0.7184466019417477
# The weakest three classes:
# 1. bears - 0.4912280701754386
# 2. elephants - 0.7184466019417477
#
# Epoch 3/3:
# Train Acc: 0.7469. Train Loss: 0.8716
# Val Acc: 0.6500. Val Loss: 1.1839
# F1-score for class : bears - 0.5172413793103448
# F1-score for class : elephants - 0.7254901960784315
# The weakest three classes:
# 1. bears - 0.5172413793103448
# 2. elephants - 0.7254901960784315
#
# --------------------------------------------------
#
# filter_size=32, lr=0.001, batch_size=128, weight_decay=0
#
# Epoch 1/3:
# Train Acc: 0.5563. Train Loss: 3.0804
# Val Acc: 0.5250. Val Loss: 5.8056
# F1-score for class : bears - 0.09523809523809523
# F1-score for class : elephants - 0.6779661016949152
# The weakest three classes:
# 1. bears - 0.09523809523809523
# 2. elephants - 0.6779661016949152
#
# Epoch 2/3:
# Train Acc: 0.6000. Train Loss: 2.9905
# Val Acc: 0.5625. Val Loss: 3.5755
# F1-score for class : bears - 0.6956521739130436
# F1-score for class : elephants - 0.2222222222222222
# The weakest three classes:
# 1. elephants - 0.2222222222222222
# 2. bears - 0.6956521739130436
#
# Epoch 3/3:
# Train Acc: 0.6594. Train Loss: 1.7042
# Val Acc: 0.5500. Val Loss: 3.6169
# F1-score for class : bears - 0.18181818181818182
# F1-score for class : elephants - 0.6896551724137931
# The weakest three classes:
# 1. bears - 0.18181818181818182
# 2. elephants - 0.6896551724137931
#
# --------------------------------------------------
#
# filter_size=32, lr=0.001, batch_size=128, weight_decay=0.0001
#
# Epoch 1/3:
# Train Acc: 0.5125. Train Loss: 4.6448
# Val Acc: 0.5000. Val Loss: 4.0117
# F1-score for class : bears - 0.6551724137931034
# F1-score for class : elephants - 0.09090909090909091
# The weakest three classes:
# 1. elephants - 0.09090909090909091
# 2. bears - 0.6551724137931034
#
# Epoch 2/3:
# Train Acc: 0.5781. Train Loss: 3.0713
# Val Acc: 0.5375. Val Loss: 5.4960
# F1-score for class : bears - 0.13953488372093023
# F1-score for class : elephants - 0.6837606837606837
# The weakest three classes:
# 1. bears - 0.13953488372093023
# 2. elephants - 0.6837606837606837
#
# Epoch 3/3:
# Train Acc: 0.5875. Train Loss: 2.2261
# Val Acc: 0.5500. Val Loss: 3.0546
# F1-score for class : bears - 0.6896551724137931
# F1-score for class : elephants - 0.18181818181818182
# The weakest three classes:
# 1. elephants - 0.18181818181818182
# 2. bears - 0.6896551724137931
#
# --------------------------------------------------
#
# filter_size=32, lr=0.0003, batch_size=64, weight_decay=0
#
# Epoch 1/3:
# Train Acc: 0.4813. Train Loss: 2.6715
# Val Acc: 0.5000. Val Loss: 2.7103
# F1-score for class : bears - 0.0
# F1-score for class : elephants - 0.6666666666666666
# The weakest three classes:
# 1. bears - 0.0
# 2. elephants - 0.6666666666666666
#
# Epoch 2/3:
# Train Acc: 0.5156. Train Loss: 1.7124
# Val Acc: 0.5125. Val Loss: 1.3793
# F1-score for class : bears - 0.6722689075630253
# F1-score for class : elephants - 0.04878048780487806
# The weakest three classes:
# 1. elephants - 0.04878048780487806
# 2. bears - 0.6722689075630253
#
# Epoch 3/3:
# Train Acc: 0.5969. Train Loss: 0.9597
# Val Acc: 0.5375. Val Loss: 1.4178
# F1-score for class : bears - 0.13953488372093023
# F1-score for class : elephants - 0.6837606837606837
# The weakest three classes:
# 1. bears - 0.13953488372093023
# 2. elephants - 0.6837606837606837
#
# --------------------------------------------------
#
# filter_size=32, lr=0.0003, batch_size=64, weight_decay=0.0001
#
# Epoch 1/3:
# Train Acc: 0.5188. Train Loss: 1.0237
# Val Acc: 0.5625. Val Loss: 1.0495
# F1-score for class : bears - 0.6902654867256637
# F1-score for class : elephants - 0.2553191489361702
# The weakest three classes:
# 1. elephants - 0.2553191489361702
# 2. bears - 0.6902654867256637
#
# Epoch 2/3:
# Train Acc: 0.5969. Train Loss: 0.8346
# Val Acc: 0.6875. Val Loss: 0.5549
# F1-score for class : bears - 0.6913580246913581
# F1-score for class : elephants - 0.6835443037974683
# The weakest three classes:
# 1. elephants - 0.6835443037974683
# 2. bears - 0.6913580246913581
#
# Epoch 3/3:
# Train Acc: 0.7625. Train Loss: 0.5050
# Val Acc: 0.6875. Val Loss: 0.6287
# F1-score for class : bears - 0.5901639344262294
# F1-score for class : elephants - 0.7474747474747475
# The weakest three classes:
# 1. bears - 0.5901639344262294
# 2. elephants - 0.7474747474747475
#
# --------------------------------------------------
#
# filter_size=32, lr=0.0003, batch_size=128, weight_decay=0
#
# Epoch 1/3:
# Train Acc: 0.5000. Train Loss: 1.5167
# Val Acc: 0.5250. Val Loss: 1.1276
# F1-score for class : bears - 0.13636363636363635
# F1-score for class : elephants - 0.6724137931034483
# The weakest three classes:
# 1. bears - 0.13636363636363635
# 2. elephants - 0.6724137931034483
#
# Epoch 2/3:
# Train Acc: 0.6500. Train Loss: 0.7392
# Val Acc: 0.6500. Val Loss: 0.6347
# F1-score for class : bears - 0.7200000000000001
# F1-score for class : elephants - 0.5333333333333333
# The weakest three classes:
# 1. elephants - 0.5333333333333333
# 2. bears - 0.7200000000000001
#
# Epoch 3/3:
# Train Acc: 0.7094. Train Loss: 0.5947
# Val Acc: 0.6125. Val Loss: 0.6517
# F1-score for class : bears - 0.4918032786885245
# F1-score for class : elephants - 0.686868686868687
# The weakest three classes:
# 1. bears - 0.4918032786885245
# 2. elephants - 0.686868686868687
#
# --------------------------------------------------
#
# filter_size=32, lr=0.0003, batch_size=128, weight_decay=0.0001
#
# Epoch 1/3:
# Train Acc: 0.4813. Train Loss: 2.0916
# Val Acc: 0.5000. Val Loss: 3.1297
# F1-score for class : bears - 0.0
# F1-score for class : elephants - 0.6666666666666666
# The weakest three classes:
# 1. bears - 0.0
# 2. elephants - 0.6666666666666666
#
# Epoch 2/3:
# Train Acc: 0.5000. Train Loss: 2.3848
# Val Acc: 0.5750. Val Loss: 0.8460
# F1-score for class : bears - 0.679245283018868
# F1-score for class : elephants - 0.37037037037037035
# The weakest three classes:
# 1. elephants - 0.37037037037037035
# 2. bears - 0.679245283018868
#
# Epoch 3/3:
# Train Acc: 0.5625. Train Loss: 1.5456
# Val Acc: 0.5875. Val Loss: 1.0427
# F1-score for class : bears - 0.7079646017699115
# F1-score for class : elephants - 0.2978723404255319
# The weakest three classes:
# 1. elephants - 0.2978723404255319
# 2. bears - 0.7079646017699115
#
# --------------------------------------------------
#
# filter_size=64, lr=0.001, batch_size=64, weight_decay=0
#
# Epoch 1/3:
# Train Acc: 0.5250. Train Loss: 10.7672
# Val Acc: 0.6125. Val Loss: 1.9533
# F1-score for class : bears - 0.6516853932584269
# F1-score for class : elephants - 0.5633802816901409
# The weakest three classes:
# 1. elephants - 0.5633802816901409
# 2. bears - 0.6516853932584269
#
# Epoch 2/3:
# Train Acc: 0.6156. Train Loss: 5.4625
# Val Acc: 0.6125. Val Loss: 3.9353
# F1-score for class : bears - 0.7207207207207207
# F1-score for class : elephants - 0.36734693877551017
# The weakest three classes:
# 1. elephants - 0.36734693877551017
# 2. bears - 0.7207207207207207
#
# Epoch 3/3:
# Train Acc: 0.6625. Train Loss: 2.8916
# Val Acc: 0.5875. Val Loss: 6.7012
# F1-score for class : bears - 0.2978723404255319
# F1-score for class : elephants - 0.7079646017699115
# The weakest three classes:
# 1. bears - 0.2978723404255319
# 2. elephants - 0.7079646017699115
#
# --------------------------------------------------
#
# filter_size=64, lr=0.001, batch_size=64, weight_decay=0.0001
#
# Epoch 1/3:
# Train Acc: 0.4781. Train Loss: 8.6664
# Val Acc: 0.5375. Val Loss: 4.8922
# F1-score for class : bears - 0.13953488372093023
# F1-score for class : elephants - 0.6837606837606837
# The weakest three classes:
# 1. bears - 0.13953488372093023
# 2. elephants - 0.6837606837606837
#
# Epoch 2/3:
# Train Acc: 0.5969. Train Loss: 3.5964
# Val Acc: 0.6375. Val Loss: 2.5787
# F1-score for class : bears - 0.7128712871287128
# F1-score for class : elephants - 0.5084745762711864
# The weakest three classes:
# 1. elephants - 0.5084745762711864
# 2. bears - 0.7128712871287128
#
# Epoch 3/3:
# Train Acc: 0.7375. Train Loss: 1.7730
# Val Acc: 0.6500. Val Loss: 1.4223
# F1-score for class : bears - 0.6410256410256411
# F1-score for class : elephants - 0.6585365853658537
# The weakest three classes:
# 1. bears - 0.6410256410256411
# 2. elephants - 0.6585365853658537
#
# --------------------------------------------------
#
# filter_size=64, lr=0.001, batch_size=128, weight_decay=0
#
# Epoch 1/3:
# Train Acc: 0.4938. Train Loss: 9.4393
# Val Acc: 0.5000. Val Loss: 15.5167
# F1-score for class : bears - 0.0
# F1-score for class : elephants - 0.6666666666666666
# The weakest three classes:
# 1. bears - 0.0
# 2. elephants - 0.6666666666666666
#
# Epoch 2/3:
# Train Acc: 0.6406. Train Loss: 7.1778
# Val Acc: 0.5375. Val Loss: 10.5546
# F1-score for class : bears - 0.6837606837606837
# F1-score for class : elephants - 0.13953488372093023
# The weakest three classes:
# 1. elephants - 0.13953488372093023
# 2. bears - 0.6837606837606837
#
# Epoch 3/3:
# Train Acc: 0.5781. Train Loss: 5.5924
# Val Acc: 0.5750. Val Loss: 9.0063
# F1-score for class : bears - 0.2608695652173913
# F1-score for class : elephants - 0.7017543859649124
# The weakest three classes:
# 1. bears - 0.2608695652173913
# 2. elephants - 0.7017543859649124
#
# --------------------------------------------------
#
# filter_size=64, lr=0.001, batch_size=128, weight_decay=0.0001
#
# Epoch 1/3:
# Train Acc: 0.5062. Train Loss: 9.8601
# Val Acc: 0.5000. Val Loss: 20.1912
# F1-score for class : bears - 0.0
# F1-score for class : elephants - 0.6666666666666666
# The weakest three classes:
# 1. bears - 0.0
# 2. elephants - 0.6666666666666666
#
# Epoch 2/3:
# Train Acc: 0.5000. Train Loss: 17.1101
# Val Acc: 0.6625. Val Loss: 2.0550
# F1-score for class : bears - 0.7096774193548386
# F1-score for class : elephants - 0.5970149253731343
# The weakest three classes:
# 1. elephants - 0.5970149253731343
# 2. bears - 0.7096774193548386
#
# Epoch 3/3:
# Train Acc: 0.6406. Train Loss: 6.4830
# Val Acc: 0.5375. Val Loss: 7.3549
# F1-score for class : bears - 0.6837606837606837
# F1-score for class : elephants - 0.13953488372093023
# The weakest three classes:
# 1. elephants - 0.13953488372093023
# 2. bears - 0.6837606837606837
#
# --------------------------------------------------
#
# filter_size=64, lr=0.0003, batch_size=64, weight_decay=0
#
# Epoch 1/3:
# Train Acc: 0.5188. Train Loss: 2.2900
# Val Acc: 0.5625. Val Loss: 1.9522
# F1-score for class : bears - 0.6846846846846846
# F1-score for class : elephants - 0.2857142857142857
# The weakest three classes:
# 1. elephants - 0.2857142857142857
# 2. bears - 0.6846846846846846
#
# Epoch 2/3:
# Train Acc: 0.6687. Train Loss: 1.2245
# Val Acc: 0.6000. Val Loss: 1.3182
# F1-score for class : bears - 0.48387096774193555
# F1-score for class : elephants - 0.6734693877551021
# The weakest three classes:
# 1. bears - 0.48387096774193555
# 2. elephants - 0.6734693877551021
#
# Epoch 3/3:
# Train Acc: 0.7250. Train Loss: 0.6541
# Val Acc: 0.6375. Val Loss: 0.9306
# F1-score for class : bears - 0.5084745762711864
# F1-score for class : elephants - 0.7128712871287128
# The weakest three classes:
# 1. bears - 0.5084745762711864
# 2. elephants - 0.7128712871287128
#
# --------------------------------------------------
#
# filter_size=64, lr=0.0003, batch_size=64, weight_decay=0.0001
#
# Epoch 1/3:
# Train Acc: 0.5094. Train Loss: 1.8423
# Val Acc: 0.6500. Val Loss: 1.8965
# F1-score for class : bears - 0.4999999999999999
# F1-score for class : elephants - 0.7307692307692308
# The weakest three classes:
# 1. bears - 0.4999999999999999
# 2. elephants - 0.7307692307692308
#
# Epoch 2/3:
# Train Acc: 0.6906. Train Loss: 1.2050
# Val Acc: 0.6625. Val Loss: 0.8461
# F1-score for class : bears - 0.7272727272727273
# F1-score for class : elephants - 0.5573770491803278
# The weakest three classes:
# 1. elephants - 0.5573770491803278
# 2. bears - 0.7272727272727273
#
# Epoch 3/3:
# Train Acc: 0.7812. Train Loss: 0.7015
# Val Acc: 0.7125. Val Loss: 1.1716
# F1-score for class : bears - 0.6567164179104479
# F1-score for class : elephants - 0.7526881720430108
# The weakest three classes:
# 1. bears - 0.6567164179104479
# 2. elephants - 0.7526881720430108
#
# --------------------------------------------------
#
# filter_size=64, lr=0.0003, batch_size=128, weight_decay=0
#
# Epoch 1/3:
# Train Acc: 0.4625. Train Loss: 4.2017
# Val Acc: 0.5000. Val Loss: 6.4256
# F1-score for class : bears - 0.0
# F1-score for class : elephants - 0.6666666666666666
# The weakest three classes:
# 1. bears - 0.0
# 2. elephants - 0.6666666666666666
#
# Epoch 2/3:
# Train Acc: 0.5000. Train Loss: 6.4451
# Val Acc: 0.5000. Val Loss: 3.3422
# F1-score for class : bears - 0.0
# F1-score for class : elephants - 0.6666666666666666
# The weakest three classes:
# 1. bears - 0.0
# 2. elephants - 0.6666666666666666
#
# Epoch 3/3:
# Train Acc: 0.5781. Train Loss: 1.9570
# Val Acc: 0.5125. Val Loss: 3.1421
# F1-score for class : bears - 0.6722689075630253
# F1-score for class : elephants - 0.04878048780487806
# The weakest three classes:
# 1. elephants - 0.04878048780487806
# 2. bears - 0.6722689075630253
#
# --------------------------------------------------
#
# filter_size=64, lr=0.0003, batch_size=128, weight_decay=0.0001
#
# Epoch 1/3:
# Train Acc: 0.5375. Train Loss: 2.8948
# Val Acc: 0.5000. Val Loss: 4.4615
# F1-score for class : bears - 0.6666666666666666
# F1-score for class : elephants - 0.0
# The weakest three classes:
# 1. elephants - 0.0
# 2. bears - 0.6666666666666666
#
# Epoch 2/3:
# Train Acc: 0.5062. Train Loss: 3.0092
# Val Acc: 0.5125. Val Loss: 2.4484
# F1-score for class : bears - 0.04878048780487806
# F1-score for class : elephants - 0.6722689075630253
# The weakest three classes:
# 1. bears - 0.04878048780487806
# 2. elephants - 0.6722689075630253
#
# Epoch 3/3:
# Train Acc: 0.6219. Train Loss: 1.2131
# Val Acc: 0.6000. Val Loss: 1.4749
# F1-score for class : bears - 0.7142857142857143
# F1-score for class : elephants - 0.33333333333333337
# The weakest three classes:
# 1. elephants - 0.33333333333333337
# 2. bears - 0.7142857142857143
#
# Best configuration:
# {'filter_size': 64, 'learning_rate': 0.0003, 'batch_size': 64, 'weight_decay': 0.0001, 'f1_macro': np.float64(0.7047022949767293), 'model': ConvolutionModel(
#   (net): Sequential(
#     (0): ConvBlock(
#       (net): Sequential(
#         (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU()
#       )
#     )
#     (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (2): Flatten(start_dim=1, end_dim=-1)
#     (3): Linear(in_features=262144, out_features=2, bias=True)
#   )
# )}
#
# Q8
# The plot was saved to /home/shuptik/pw/sem6/ann/AnimalImageClassification/plots/confusion_matrix_heatmap.png
#
# Q9
# Results were successfully written to /home/shuptik/pw/sem6/ann/AnimalImageClassification/testing/results.csv
